# %%
import numpy as np
import matplotlib.pyplot as plt

# Honey production values (tonnes)
honey_production = np.array([2642, 4491, 4391, 4129, 3600, 4277, 3912, 
                             3742, 4763, 4247, 3076, 4784, 2815, 3790, 
                             3458, 3318, 4776, 3740, 3338, 3219, 
                             4824, 3903, 3456, 4055, 3759, 2708, 
                             2081, 2600, 3999, 4093, 4281, 2886, 
                             4798, 4070, 4028, 2761, 3707, 3612, 
                             3872, 2904, 3443, 3207])

# Years
years = np.array([1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 
                  1990, 1991, 1992, 1993, 1994, 1995, 1996, 
                  1997, 1998, 1999, 2000, 2001, 2002, 2003, 
                  2004, 2005, 2006, 2007, 2008, 2009, 2010, 
                  2011, 2012, 2013, 2014, 2015, 2016, 2017, 
                  2018, 2019, 2020, 2021, 2022, 2023])

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 5))

# Create a horizontal bar graph with honey production on the x-axis and years on the y-axis
ax.barh(years, honey_production, color='indigo')

# Set labels and title
ax.set_xlabel('Honey Production (tonnes)', fontsize=12)
ax.set_ylabel('Year', fontsize=12)
ax.set_title('Honey Production per Year (tonnes)', fontsize=14)

# Add grid lines
ax.grid(axis='x', linestyle='--', alpha=0.7)

# Display the graph
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Honey production values (tonnes)
honey_production = np.array([2642, 4491, 4391, 4129, 3600, 4277, 3912, 
                             3742, 4763, 4247, 3076, 4784, 2815, 3790, 
                             3458, 3318, 4776, 3740, 3338, 3219, 
                             4824, 3903, 3456, 4055, 3759, 2708, 
                             2081, 2600, 3999, 4093, 4281, 2886, 
                             4798, 4070, 4028, 2761, 3707, 3612, 
                             3872, 2904, 3443, 3207])

# Years
years = np.array([1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 
                  1990, 1991, 1992, 1993, 1994, 1995, 1996, 
                  1997, 1998, 1999, 2000, 2001, 2002, 2003, 
                  2004, 2005, 2006, 2007, 2008, 2009, 2010, 
                  2011, 2012, 2013, 2014, 2015, 2016, 2017, 
                  2018, 2019, 2020, 2021, 2022, 2023])

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 5))

# Create a horizontal bar graph with honey production on the x-axis and years on the y-axis
ax.bar(years, honey_production)

# Set labels and title
ax.set_ylabel('Honey Production (tonnes)', fontsize=12)
ax.set_xlabel('Year', fontsize=12)
ax.set_title('Honey Production per Year (tonnes)', fontsize=14)

# Add grid lines
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Display the graph
plt.tight_layout()
plt.show()

# %% [markdown]
# Image from Tableau Public showing the complete dashboard
#
# ![Image1.png](attachment:Image1.png)

# %% [markdown]
# Image from Tableau Public with just the line graph
#
# ![Image2.png](attachment:Image2.png)
